# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import skrf as rf
rf.stylely()
from pylab import *

# %%
# load data for the waveguide to CPW probe
signals = list()
#signals.append(rf.Network('./Amphenol SMA Launcher_SMA Back to Back.s2p'))
#signals.append(rf.Network('./Amphenol SMA Launcher_SMA Launcher.s1p'))
#signals.append(rf.Network('./Amphenol SMA Launcher_SMA Back to Back3.s2p'))
#signals.append(rf.Network('./Amphenol SMA Launcher_SMA Back to Back4.s2p'))
#signals.append(rf.Network('./Amphenol SMA Launcher_cpwg.s2p'))
#signals.append(rf.Network('./Amphenol SMA Launcher_cpwg2.s2p'))
#signals.append(rf.Network('./Amphenol SMA Launcher_cpwg3.s2p'))
signals.append(rf.Network('./Amphenol SMA Launcher_cpwg_042.s2p'))
signals.append(rf.Network('./Amphenol SMA Launcher_cpwg_043.s2p'))
signals.append(rf.Network('./Amphenol SMA Launcher_cpwg_044.s2p'))
signals.append(rf.Network('./Amphenol SMA Launcher_cpwg_045.s2p'))
signals.append(rf.Network('./Amphenol SMA Launcher_cpwg_045-fine.s2p'))
signals.append(rf.Network('./Amphenol SMA Launcher_cpwg_046.s2p'))
signals.append(rf.Network('./Amphenol SMA Launcher_cpwg_047.s2p'))
signals.append(rf.Network('./Amphenol SMA Launcher_cpwg_048.s2p'))

# %%
# we will focus on s11
s11 = [s.s11.extrapolate_to_dc(kind='linear') for s in signals]
#[s.interpolate_self(2001) for s in signals]

#  time-gate the first largest reflection
#s11_g = [s.time_gate(center=0, span=2,) for s in s11]

# plot frequency and time-domain s-parameters
figure(figsize=(8,6))

[s.plot_z_time_step(window='hamming') for s in s11]

plt.ylim((45,56))
plt.xlim((-0.1, 0.6))
plt.legend(bbox_to_anchor=(0.5, -0.35), loc='lower center', borderaxespad=0)
title('Time Domain')
tight_layout()
